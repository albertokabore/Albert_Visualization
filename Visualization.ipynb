# %% [markdown]
# 1. Matplotlib:  https://matplotlib.org/
#
# 2. Seaborn:  https://seaborn.pydata.org/
#
# 3. Plotly: https://plotly.com/
#
# 4. Altair: https://altair-viz.github.io/
#
# 5. ggplot: https://pypi.org/project/ggplot/

# %% [markdown]
# # What is Matplotlib?
# - Static Plotting
# - Low level graph
# - 2d Format
# - Open Source
# - Compatible with C and Javascript too

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\alber\albert_visualization\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
# !pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         3.0.0
# colorama          0.4.6
# comm              0.2.2
# contourpy         1.3.1
# cycler            0.12.1
# debugpy           1.8.12
# decorator         5.1.1
# executing         2.1.0
# fonttools         4.55.4
# ipykernel         6.29.5
# ipython           8.31.0
# jedi              0.19.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# kiwisolver        1.4.8
# matplotlib        3.10.0
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.2.2
# packaging         24.2
# pandas            2.2.3
# parso             0.8.4
# pillow            11.1.0
# pip               24.2
# platformdirs      4.3.6
# plotly            5.24.1
# prompt_toolkit    3.0.50
# psutil            6.1.1
# pure_eval         0.2.3
# Pygments          2.19.1
# pyparsing         3.2.1
# python-dateutil   2.9.0.post0
# pytz              2024.2
# pywin32           308
# pyzmq             26.2.0
# seaborn           0.13.2
# six               1.17.0
# stack-data        0.6.3
# tenacity          9.0.0
# tornado           6.4.2
# traitlets         5.14.3
# tzdata            2025.1
# wcwidth           0.2.13

# %%
import matplotlib.pyplot as plt

# %%
#Draw a diagram from position (1,1) to position (20, 300)
import numpy as np

x = (1, 20)
y = (1, 300)

plt.plot(x, y)
plt.show()

# %%
#Marker point
import numpy as np

x = (1, 20)
y = (1, 300)

plt.plot(x, y, 'o')
plt.show()

# %%
#Multiple datapoints
import numpy as np

x = (1, 5, 18, 31)
y = (14, 38, 10, 56)

plt.plot(x, y, marker = 'o')
plt.show()

# %%
#Multiple datapoints
import numpy as np

x = (1, 5, 18, 31)
y = (14, 38, 10, 56)

plt.plot(x, y, marker = '*', ms = 20, mec = 'r', mfc = 'y')
plt.show()

# %%
#Multiple datapoints
import numpy as np

x = (1, 5, 18, 31)
y = (14, 38, 10, 56)

plt.plot(x, y, ls = '--', marker = '^', ms = 20, mec = 'r', mfc = 'y')
plt.show()

# %%
#Multiple datapoints
import numpy as np

x = (1, 5, 18, 31)
y = (14, 38, 10, 56)

plt.plot(x, y, 'p-.g')
plt.show()

# %%
#Multiple datapoints
import numpy as np

x = (1, 5, 18, 31)
y = (14, 38, 10, 56)

plt.plot(x, y, ls = '--', linewidth = 5, marker = '^', ms = 20, mec = 'r', mfc = 'y')
plt.show()

# %%
#Label
x = np.array([10, 15, 20, 25, 30, 35, 40])
y = np.array([25, 36, 42, 55, 62, 56, 49])

font1 = {'family': 'serif', 'color': 'green', 'size': 20}

plt.plot(x, y)
plt.xlabel('Average Hours')
plt.ylabel('Average Score')
plt.title('Line Chart', fontdict= font1, loc = 'right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.array([10, 15, 20, 25, 30, 35, 40])  # X-axis values representing Average Hours spent studying
y = np.array([25, 36, 42, 55, 62, 56, 49])  # Y-axis values representing Average Scores obtained

# Setting font properties for the title
font1 = {'family': 'serif', 'color': 'green', 'size': 20}

# Creating a line plot
plt.plot(x, y)

# Label for X-axis
plt.xlabel('Average Hours')

# Label for Y-axis
plt.ylabel('Average Score')

# Adding a title with custom font settings and aligning it to the right
plt.title('Line Chart', fontdict=font1, loc='right')

# Adding a grid, but only for the Y-axis
plt.grid(axis='y')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data1
x1 = np.array([10, 15, 20, 25, 30, 35, 40])
y1 = np.array([25, 36, 42, 55, 62, 56, 49])

# Data2
x2 = np.array([5, 10, 10, 15, 20, 25, 30])
y2 = np.array([22, 16, 32, 65, 42, 36, 59])

# Plotting Data1 with green line
plt.plot(x1, y1, color='green', label='Dataset 1')

# Plotting Data2 with red line
plt.plot(x2, y2, color='red', label='Dataset 2')

# Adding title and labels
font1 = {'family': 'serif', 'color': 'green', 'size': 20}
plt.title('Comparison of Two Datasets', fontdict=font1)

plt.xlabel('X Values')
plt.ylabel('Y Values')

# Adding legend to differentiate the two datasets
plt.legend()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data1
x1 = np.array([10, 15, 20, 25, 30, 35, 40])
y1 = np.array([25, 36, 42, 55, 62, 56, 49])

# Data2
x2 = np.array([5, 10, 10, 15, 20, 25, 30])
y2 = np.array([22, 16, 32, 65, 42, 36, 59])

# Plotting Data1 with green scatter points
plt.scatter(x1, y1, color='green', label='Dataset 1')

# Plotting Data2 with red scatter points
plt.scatter(x2, y2, color='red', label='Dataset 2')

# Adding title and labels
font1 = {'family': 'serif', 'color': 'green', 'size': 20}
plt.title('Scatter Plot Comparison', fontdict=font1)
plt.xlabel('X Values')
plt.ylabel('Y Values')

# Adding legend to differentiate the two datasets
plt.legend()

# Show plot
plt.show()

# %%
# !pip install pandas
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\alber\albert_visualization\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
x = np.linspace(0, 10, 100)  # Generate 100 points from 0 to 10
y = np.sin(x) + np.random.normal(0, 0.1, 100)  # Create noisy sine wave

# Create a DataFrame
df = pd.DataFrame({'x': x, 'y': y})

# Apply rolling mean (smoothing)
window_size = 3  # Define the window size for smoothing
df['y_smooth'] = df['y'].rolling(window=window_size).mean()  # Calculate rolling mean

# Plot original noisy data
plt.plot(df['x'], df['y'], label='Original Data', alpha=0.5)

# Plot smoothed data
plt.plot(df['x'], df['y_smooth'], label='Smoothed Data', color='blue')

# Add a legend to differentiate the two plots
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
x = np.linspace(-10, 10, 100)  # Generate 100 points between -10 and 10
y = x**2 + np.random.normal(0, 10, 100)  # Create noisy parabola (y = x^2 + noise)

# Create a DataFrame
df = pd.DataFrame({'x': x, 'y': y})

# Apply rolling mean (smoothing)
window_size = 5  # Define the window size for smoothing
df['y_smooth'] = df['y'].rolling(window=window_size).mean()  # Calculate rolling mean

# Plot original noisy data
plt.plot(df['x'], df['y'], label='Original', alpha=0.5)

# Plot smoothed data (rolling mean)
plt.plot(df['x'], df['y_smooth'], label='Smoothed Parabola', color='green')

# Add a legend to differentiate the two plots
plt.legend()

# Display the plot
plt.show()

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\alber\albert_visualization\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\alber\albert_visualization\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To check all datasets
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
data = sns.load_dataset('diamonds')
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a scatter plot using seaborn
sns.scatterplot(data=data, x='carat', y='price', hue='cut')

# Add title and labels
plt.title('Scatter Plot: Carat vs. Price by Cut')
plt.xlabel('Carat')
plt.ylabel('Price ($)')

# Display the plot
plt.show()

# %%
# Box plot of diamond price by cut
sns.boxplot(data=data, x='cut', y='price')
plt.title('Box Plot of Diamond Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price ($)')
plt.show()

# %%
# Violin plot of diamond price by cut
sns.violinplot(data=data, x='cut', y='price')
plt.title('Violin Plot of Diamond Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price ($)')
plt.show()

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Scatter Plot: Cut, price, carat
sns.scatterplot(data = df, x='sepal_length', y='petal_length', hue = 'species')
plt.title('Scatter Plot')
plt.ylabel('Price ($)')
plt.show()

# %%
#Stacked Bar Chart: Cut, price, carat
pivot_data = data.pivot_table(index = 'color', columns = 'cut', values='price', aggfunc='mean')
pivot_data.plot(kind='bar', stacked =True)
plt.show()
# Out:
# C:\Users\alber\AppData\Local\Temp\ipykernel_26608\3812444118.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_data = data.pivot_table(index = 'color', columns = 'cut', values='price', aggfunc='mean')

# %%
#violin Plot: cut, color, price
sns.violinplot(data = df, x='sepal_length', y='petal_length', hue='species', split=True )
plt.title('Violin Plot')
plt.show()

# %%
# Joint plot for carat and price
sns.jointplot(data=data, x='carat', y='price', kind='scatter')
plt.title('Joint Plot of Carat and Price')
plt.show()

# %%
# Swarm plot of diamond price by cut
sns.swarmplot(data=data, x='cut', y='price')
plt.title('Swarm Plot of Diamond Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price ($)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Swarm plot of diamond price by cut
# ----> 2 sns.swarmplot(data=data, x='cut', y='price')
#       3 plt.title('Swarm Plot of Diamond Price by Cut')
#       4 plt.xlabel('Cut')
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:2250, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2242     linewidth = size / 10
#    2244 kwargs.update(dict(
#    2245     s=size ** 2,
#    2246     edgecolor=edgecolor,
#    2247     linewidth=linewidth,
#    2248 ))
# -> 2250 p.plot_swarms(
#    2251     dodge=dodge,
#    2252     color=color,
#    2253     warn_thresh=warn_thresh,
#    2254     plot_kws=kwargs,
#    2255 )
#    2257 p._add_axis_labels(ax)
#    2258 p._adjust_cat_axis(ax, axis=p.orient)
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:588, in _CategoricalPlotter.plot_swarms(self, dodge, color, warn_thresh, plot_kws)
#     584             super(points.__class__, points).draw(renderer)
#     586         points.draw = draw.__get__(points)
# --> 588 _draw_figure(ax.figure)
#     589 self._configure_legend(ax, _scatter_legend_artist, plot_kws)
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\utils.py:61, in _draw_figure(fig)
#      59 """Force draw of a matplotlib figure, accounting for back-compat."""
#      60 # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 61 fig.canvas.draw()
#      62 if fig.stale:
#      63     try:
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\backends\backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\axes\_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:566, in _CategoricalPlotter.plot_swarms.<locals>.draw(points, renderer, center)
#     564 def draw(points, renderer, *, center=center):
# --> 566     beeswarm(points, center)
#     568     if self.orient == "y":
#     569         scalex = False
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:3263, in Beeswarm.__call__(self, points, center)
#    3261 # Adjust points along the categorical axis to prevent overlaps
#    3262 new_xyr = np.empty_like(orig_xyr)
# -> 3263 new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3265 # Transform the point coordinates back to data coordinates
#    3266 if self.orient == "y":
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:3310, in Beeswarm.beeswarm(self, orig_xyr)
#    3307 candidates = candidates[np.argsort(offsets)]
#    3309 # Find the first candidate that does not overlap any neighbors
# -> 3310 new_xyr_i = self.first_non_overlapping_candidate(candidates, neighbors)
#    3312 # Place it into the swarm
#    3313 swarm = np.vstack([swarm, new_xyr_i])
#
# File c:\Users\alber\Albert_Visualization\.venv\Lib\site-packages\seaborn\categorical.py:3365, in Beeswarm.first_non_overlapping_candidate(self, candidates, neighbors)
#    3363 dx = neighbors_x - x_i
#    3364 dy = neighbors_y - y_i
# -> 3365 sq_distances = np.square(dx) + np.square(dy)
#    3367 sep_needed = np.square(neighbors_r + r_i)
#    3369 # Good candidate does not overlap any of neighbors which means that
#    3370 # squared distance between candidate and any of the neighbors has
#    3371 # to be at least square of the summed radii
#
# KeyboardInterrupt:

# %%
# Count plot of diamond cuts
sns.countplot(data=data, x='cut')
plt.title('Count of Diamonds by Cut')
plt.xlabel('Cut')
plt.ylabel('Count')
plt.show()

# %%
# !pip install plotly

# %%
import plotly.express as px

# %%
gap = px.data.gapminder()
gap.head()

# %%
fig = px.scatter(gap, x='gdpPercap', y='lifeExp', animation_frame ='year', animation_group ='country',
                     size = 'pop', color='continent', hover_name = 'country',
                     log_x = True, size_max = 60,
                     title = "Life Expectancy vs GDP Per capita")

fig.show()

# %%
import plotly.express as px

# Load the gapminder dataset
gap = px.data.gapminder()

# Scatter plot of Life Expectancy vs. GDP per Capita
scatter_plot = px.scatter(gap, x='gdpPercap', y='lifeExp', color='continent',
                          hover_name='country', log_x=True, size='pop',
                          title="Life Expectancy vs. GDP per Capita (Log Scale)",
                          labels={"gdpPercap": "GDP per Capita", "lifeExp": "Life Expectancy"},
                          animation_frame='year')

# Show the plot
scatter_plot.show()

# %%
fig = px.sunburst(gap, path = ['continent', 'country'], values ='lifeExp', color ='country', title = 'Sunburst Chart')

fig.show()

# %%
# Line plot of Life Expectancy over time for each continent
line_plot = px.line(gap, x='year', y='lifeExp', color='continent',
                    title="Life Expectancy Over Time by Continent",
                    labels={"lifeExp": "Life Expectancy", "year": "Year"})

# Show the plot
line_plot.show()

# %%
# Filter the data for the year 2007
gap_2007 = gap[gap['year'] == 2007]

# Bar plot of Population by Continent in 2007
bar_plot = px.bar(gap_2007, x='continent', y='pop',
                  title="Population by Continent in 2007",
                  labels={"pop": "Population", "continent": "Continent"},
                  color='continent')

# Show the plot
bar_plot.show()

# %%
# Box plot of GDP per Capita by Continent
box_plot = px.box(gap, x='continent', y='gdpPercap',
                  title="GDP per Capita Distribution by Continent",
                  labels={"gdpPercap": "GDP per Capita", "continent": "Continent"})

# Show the plot
box_plot.show()

# %%
# Choropleth map of Life Expectancy in 2007
choropleth_map = px.choropleth(gap_2007, locations='iso_alpha', color='lifeExp',
                               hover_name='country',
                               title="Life Expectancy Around the World in 2007",
                               color_continuous_scale=px.colors.sequential.Plasma)

# Show the plot
choropleth_map.show()

# %%
# !pip install altair vega_datasets

# %%
import altair as alt
from vega_datasets import data

# %%
cars = data.cars()
cars.head()

# %% [markdown]
# The dataset contains the following columns:
#
# Name: The name of the car.
# Miles_per_Gallon: Fuel efficiency in miles per gallon.
# Cylinders: Number of engine cylinders.
# Displacement: Engine displacement in cubic inches.
# Horsepower: Engine horsepower.
# Weight_in_lbs: Weight of the car in pounds.
# Acceleration: Time to accelerate from 0 to 60 mph (in seconds).
# Year: Year of the car's model.
# Origin: Country of origin (USA, Europe, or Japan).

# %%
import altair as alt
from vega_datasets import data

# Load the cars dataset
cars = data.cars()

# Create a scatter plot
scatter_plot = alt.Chart(cars).mark_circle(size=60).encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Name', 'Horsepower', 'Miles_per_Gallon', 'Origin']
).properties(
    title='Horsepower vs. Miles per Gallon'
)

scatter_plot

# %%
# Create a bar chart
bar_chart = alt.Chart(cars).mark_bar().encode(
    x='count()',
    y = 'Origin',
    color = 'Origin'
).interactive()

bar_chart

# %%
# Create a histogram
histogram = alt.Chart(cars).mark_bar().encode(
    alt.X('Horsepower', bin=alt.Bin(maxbins=30)),
    y='count()',
    tooltip=['Horsepower', 'count()']
).properties(
    title='Distribution of Horsepower'
)

histogram

# %%
# Create a line chart
line_chart = alt.Chart(cars).mark_line().encode(
    x='Year:T',
    y='average(Weight_in_lbs)',
    color='Origin'
).properties(
    title='Average Weight of Cars Over Time'
)

line_chart

# %%
# !pip install plotnine

# %%
from plotnine import ggplot, aes, geom_point, ggtitle, xlab, ylab
from plotnine.data import mpg

mpg.info()

# %%
from plotnine import ggplot, aes, geom_point, ggtitle, xlab, ylab
from plotnine.data import mpg

# Scatter plot for engine displacement vs highway MPG
scatter_plot = (ggplot(mpg, aes(x='displ', y='hwy', color='class')) +
                geom_point() +
                ggtitle('Displacement vs. Highway MPG') +
                xlab('Engine Displacement (Liters)') +
                ylab('Highway MPG'))

print(scatter_plot)

# %%
from plotnine import geom_boxplot

# Box plot for city MPG by number of cylinders
box_plot = (ggplot(mpg, aes(x='factor(cyl)', y='cty', fill='factor(cyl)')) +
            geom_boxplot() +
            ggtitle('City MPG by Number of Cylinders') +
            xlab('Number of Cylinders') +
            ylab('City MPG'))

print(box_plot)

# %%
from plotnine import facet_wrap

# Facet plot for engine displacement vs highway MPG by drive type
facet_plot = (ggplot(mpg, aes(x='displ', y='hwy')) +
              geom_point() +
              facet_wrap('~drv') +
              ggtitle('Displacement vs. Highway MPG by Drive Type') +
              xlab('Engine Displacement (Liters)') +
              ylab('Highway MPG'))

print(facet_plot)

# %%
from plotnine import ggplot, aes, geom_histogram, ggtitle, xlab, ylab, theme, element_rect, element_line

hist = (ggplot(mpg, aes(x='displ')) +
        geom_histogram(bins=30, fill='yellow', color='black') +
        theme (
            panel_background=element_rect(fill='lightblue'),
            panel_grid_major=element_line(color='white')
        )+
        ggtitle('Histogram'))

print(hist)

# %%
# !pip install folium

# %%
import folium

sf = folium.Map(location=[37.773972, -122.431297], zoom_start= 12)

sf

# %%
import folium

# Create a map centered around San Francisco
sf = folium.Map(location=[37.773972, -122.431297], zoom_start=12)

# Add markers for notable places in San Francisco
folium.Marker([37.7749, -122.4194], popup='San Francisco').add_to(sf)
folium.Marker([37.8080, -122.4177], popup='Fisherman’s Wharf').add_to(sf)
folium.Marker([37.8199, -122.4783], popup='Golden Gate Bridge').add_to(sf)

sf

# %%
# Add circle markers for landmarks
folium.CircleMarker(
    location=[37.8199, -122.4783],
    radius=50,
    popup='Golden Gate Bridge',
    color='red',
    fill=True,
    fill_color='red'
).add_to(sf)

folium.CircleMarker(
    location=[37.8021, -122.4187],
    radius=30,
    popup='Coit Tower',
    color='blue',
    fill=True,
    fill_color='blue'
).add_to(sf)

sf

# %%
import folium
import pandas as pd

# Example population data for US states
state_data = pd.DataFrame({
    'State': ['California', 'Texas', 'New York', 'Florida', 'Illinois'],
    'Population': [39538223, 29145505, 20201249, 21538187, 12812508]
})

# Create a base map
map_choropleth = folium.Map(location=[37.0902, -95.7129], zoom_start=5)

# Add choropleth (dummy geojson file for demonstration purposes)
folium.Choropleth(
    geo_data='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json',
    name='choropleth',
    data=state_data,
    columns=['State', 'Population'],
    key_on='feature.id',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population by State'
).add_to(map_choropleth)

map_choropleth

# %%
from folium.plugins import HeatMap

# Sample data: Latitude and Longitude points
heat_data = [[37.7749, -122.4194], [37.8080, -122.4177], [37.8199, -122.4783],
             [37.7849, -122.3994], [37.7699, -122.4244], [37.7839, -122.4324]]

# Add HeatMap
HeatMap(heat_data).add_to(sf)

sf

# %%
# !pip install dash

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
import pandas as pd

# Sample data
df = px.data.gapminder()

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Country Population Dashboard", style={'text-align': 'center'}),

    # Dropdown for selecting a year
    dcc.Dropdown(
        id='year-dropdown',
        options=[{'label': str(year), 'value': year} for year in df['year'].unique()],
        value=2007,  # Default value
        clearable=False,
        style={'width': '50%', 'margin': 'auto'}
    ),

    # Graph for population
    dcc.Graph(id='population-graph'),
])

# Define callback to update graph based on dropdown input
@app.callback(
    Output('population-graph', 'figure'),
    [Input('year-dropdown', 'value')]
)
def update_graph(selected_year):
    filtered_df = df[df['year'] == selected_year]
    fig = px.bar(filtered_df, x='country', y='pop', title=f'Population in {selected_year}', labels={'pop': 'Population'})
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import dash
from dash import dcc, html
import plotly.express as px

# Initialize the Dash app
app = dash.Dash(__name__)

# Sample data
df = px.data.gapminder()

# Create a Plotly figure (Line Chart)
fig = px.line(df[df['country'] == 'India'], x='year', y='gdpPercap', title='GDP per Capita of India Over Time')

# Layout of the dashboard
app.layout = html.Div(children=[
    html.H1(children='Dash Dashboard'),
    dcc.Graph(
        id='example-line-chart',
        figure=fig
    )
])

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

# Sample data
df = px.data.tips()

# Create a Plotly figure (Histogram)
fig = px.histogram(df, x='total_bill', nbins=20, title="Histogram of Total Bill")

# Layout of the dashboard
app.layout = html.Div(children=[
    html.H1(children='Histogram Example'),
    dcc.Graph(
        id='example-histogram',
        figure=fig
    )
])

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

# Initialize the app
app = dash.Dash(__name__)

# Load the Gapminder dataset
df = px.data.gapminder()

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Gapminder Dashboard with Multiple Graphs", style={'textAlign': 'center'}),

    # Row 1: Scatter Plot and Bar Chart side by side
    html.Div([
        html.Div([
            dcc.Dropdown(
                id='scatter-continent-dropdown',
                options=[{'label': continent, 'value': continent} for continent in df['continent'].unique()],
                value='Asia',  # Default continent
                clearable=False,
                style={'width': '50%', 'margin': 'auto'}
            ),
            dcc.Graph(id='scatter-plot'),
        ], style={'width': '48%', 'display': 'inline-block'}),

        html.Div([
            dcc.Graph(id='bar-chart'),
        ], style={'width': '48%', 'display': 'inline-block'})
    ]),

    # Row 2: Line Chart spanning the entire width
    html.Div([
        dcc.Graph(id='line-chart')
    ], style={'width': '100%', 'display': 'inline-block'})
])

# Callback to update the scatter plot based on selected continent
@app.callback(
    dash.dependencies.Output('scatter-plot', 'figure'),
    [dash.dependencies.Input('scatter-continent-dropdown', 'value')]
)
def update_scatter(selected_continent):
    filtered_df = df[df['continent'] == selected_continent]
    fig = px.scatter(filtered_df, x='gdpPercap', y='lifeExp', color='country',
                     title=f"Life Expectancy vs GDP per Capita in {selected_continent}",
                     log_x=True, size='pop', hover_name='country', size_max=60)
    return fig

# Callback to update the bar chart for population by continent
@app.callback(
    dash.dependencies.Output('bar-chart', 'figure'),
    [dash.dependencies.Input('scatter-continent-dropdown', 'value')]
)
def update_bar(selected_continent):
    filtered_df = df[df['continent'] == selected_continent]
    pop_df = filtered_df.groupby('country').agg({'pop': 'sum'}).reset_index()
    fig = px.bar(pop_df, x='country', y='pop', title=f"Total Population by Country in {selected_continent}")
    return fig

# Callback to update the line chart for life expectancy over time
@app.callback(
    dash.dependencies.Output('line-chart', 'figure'),
    [dash.dependencies.Input('scatter-continent-dropdown', 'value')]
)
def update_line(selected_continent):
    filtered_df = df[df['continent'] == selected_continent]
    fig = px.line(filtered_df, x='year', y='lifeExp', color='country',
                  title=f"Life Expectancy Over Time in {selected_continent}")
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
